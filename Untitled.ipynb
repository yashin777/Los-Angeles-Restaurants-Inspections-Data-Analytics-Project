# %% [markdown]
# # Los Angeles Restaruants Violations Data Analytics Project

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("inspections.csv")
df2=pd.read_csv("violations.csv")

# %%
df1
# Out:
#        activity_date employee_id           facility_address  facility_city  \
# 0         2017-05-09   EE0000593        17660 CHATSWORTH ST  GRANADA HILLS
# 1         2017-04-10   EE0000126     3615 PACIFIC COAST HWY       TORRANCE
# 2         2017-04-04   EE0000593        17515 CHATSWORTH ST  GRANADA HILLS
# 3         2017-08-15   EE0000971   44455 VALLEY CENTRAL WAY      LANCASTER
# 4         2016-09-26   EE0000145             11700 SOUTH ST        ARTESIA
# ...              ...         ...                        ...            ...
# 191366    2016-05-10   EE0000946              3461 W 3RD ST    LOS ANGELES
# 191367    2016-08-17   EE0000018  15420 S WESTERN AVE STE A        GARDENA
# 191368    2016-06-30   EE0000029         11976 ARTESIA BLVD        ARTESIA
# 191369    2016-12-06   EE0000860             1430 W 25TH ST      SAN PEDRO
# 191370    2017-03-20   EE0000800          1654 W ADAMS BLVD    LOS ANGELES
#
#        facility_id               facility_name facility_state facility_zip  \
# 0        FA0175397  HOVIK'S FAMOUS MEAT & DELI             CA        91344
# 1        FA0242138              SHAKEY'S PIZZA             CA        90505
# 2        FA0007801              BAITH AL HALAL             CA        91344
# 3        FA0013858            FOOD 4 LESS #306             CA        93536
# 4        FA0179671           PHO LITTLE SAIGON             CA        90701
# ...            ...                         ...            ...          ...
# 191366   FA0053958                 VONS MARKET             CA        90005
# 191367   FA0174778                 MOANA GRILL             CA        90249
# 191368   FA0029343                  QUEST CAFE             CA        90701
# 191369   FA0043987   PINA'S MEXICAN RESTAURANT             CA        90731
# 191370   FA0045805             RINCON HODURENO             CA        90007
#
#        grade   owner_id                      owner_name  \
# 0          A  OW0181955  JOHN'S FAMOUS MEAT & DELI INC.
# 1          A  OW0237843                        SCO, LLC
# 2          A  OW0031150           SABIR MOHAMMAD SHAHID
# 3          A  OW0012108               FOOD 4 LESS, INC.
# 4          A  OW0185167                PHO SOUTH ST INC
# ...      ...        ...                             ...
# 191366     A  OW0038181         THE VONS COMPANIES INC.
# 191367     A  OW0181412               MUHAN GLOBAL, INC
# 191368     A  OW0018341                       KAN, ANDY
# 191369     A  OW0022835        MAGANA, HORTA AND MARTIN
# 191370     A  OW0005012              BONILLA, ADAN LUIS
#
#                                  pe_description  program_element_pe  \
# 0       FOOD MKT RETAIL (25-1,999 SF) HIGH RISK                1612
# 1           RESTAURANT (61-150) SEATS HIGH RISK                1638
# 2       FOOD MKT RETAIL (25-1,999 SF) HIGH RISK                1612
# 3             RESTAURANT (0-30) SEATS HIGH RISK                1632
# 4           RESTAURANT (61-150) SEATS HIGH RISK                1638
# ...                                         ...                 ...
# 191366         RESTAURANT (0-30) SEATS LOW RISK                1630
# 191367        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 191368       RESTAURANT (31-60) SEATS HIGH RISK                1635
# 191369       RESTAURANT (31-60) SEATS HIGH RISK                1635
# 191370        RESTAURANT (0-30) SEATS HIGH RISK                1632
#
#                        program_name program_status  record_id  score  \
# 0        HOVIK'S FAMOUS MEAT & DELI         ACTIVE  PR0168541     98
# 1                    SHAKEY'S PIZZA         ACTIVE  PR0190290     94
# 2                    BAITH AL HALAL       INACTIVE  PR0036723     95
# 3       FOOD 4 LESS DELI/BAKERY#306         ACTIVE  PR0039905     98
# 4                 PHO LITTLE SAIGON         ACTIVE  PR0173311     96
# ...                             ...            ...        ...    ...
# 191366                    STARBUCKS         ACTIVE  PR0021549     98
# 191367                  MOANA GRILL         ACTIVE  PR0167828     92
# 191368                   QUEST CAFE       INACTIVE  PR0042814     90
# 191369    PINA'S MEXICAN RESTAURANT         ACTIVE  PR0042806     92
# 191370              RINCON HODURENO         ACTIVE  PR0028225     95
#
#        serial_number  service_code service_description
# 0          DAHDRUQZO             1  ROUTINE INSPECTION
# 1          DAL3SBUE0             1  ROUTINE INSPECTION
# 2          DAL2PIKJU             1  ROUTINE INSPECTION
# 3          DA0ZMAJXZ             1  ROUTINE INSPECTION
# 4          DA41DBXA2             1  ROUTINE INSPECTION
# ...              ...           ...                 ...
# 191366     DAQW0V2BJ             1  ROUTINE INSPECTION
# 191367     DAV0HVX0C             1  ROUTINE INSPECTION
# 191368     DATL8XDYB             1  ROUTINE INSPECTION
# 191369     DA3FOEGAF             1  ROUTINE INSPECTION
# 191370     DAOU061N2             1  ROUTINE INSPECTION
#
# [191371 rows x 20 columns]

# %%
df1['score']
# Out:
# 0         98
# 1         94
# 2         95
# 3         98
# 4         96
#           ..
# 191366    98
# 191367    92
# 191368    90
# 191369    92
# 191370    95
# Name: score, Length: 191371, dtype: int64

# %%
df2
# Out:
#         points serial_number violation_code  \
# 0            1     DAJ5UNMSF           F044
# 1            4     DAT2HKIRE           F007
# 2            1     DAT2HKIRE           F033
# 3            1     DAT2HKIRE           F035
# 4            1     DAQN0I8EA           F033
# ...        ...           ...            ...
# 906009       1     DANVC18XM           F034
# 906010       2     DAFICC8TU           F014
# 906011       1     DAK5CJ7VO           F043
# 906012       1     DAZ6F4RGR           F025
# 906013       1     DAIHLN68K           F033
#
#                                     violation_description   violation_status
# 0       # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 1          # 07. Proper hot and cold holding temperatures  OUT OF COMPLIANCE
# 2       # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
# 3       # 35. Equipment/Utensils - approved; installed...  OUT OF COMPLIANCE
# 4       # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
# ...                                                   ...                ...
# 906009  # 34. Warewashing facilities: Adequate, mainta...  OUT OF COMPLIANCE
# 906010   # 14. Food contact surfaces: clean and sanitized  OUT OF COMPLIANCE
# 906011  # 43. Premises; personal/cleaning items; vermi...  OUT OF COMPLIANCE
# 906012     # 25. Personal cleanliness and hair restraints  OUT OF COMPLIANCE
# 906013  # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
#
# [906014 rows x 5 columns]

# %%
gradeA=df1['grade']=='B'
gradeA
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 191366    False
# 191367    False
# 191368    False
# 191369    False
# 191370    False
# Name: grade, Length: 191371, dtype: bool

# %%
df2['violation_description']
# Out:
# 0         # 44. Floors, walls and ceilings: properly bui...
# 1            # 07. Proper hot and cold holding temperatures
# 2         # 33. Nonfood-contact surfaces clean and in go...
# 3         # 35. Equipment/Utensils - approved; installed...
# 4         # 33. Nonfood-contact surfaces clean and in go...
#                                 ...
# 906009    # 34. Warewashing facilities: Adequate, mainta...
# 906010     # 14. Food contact surfaces: clean and sanitized
# 906011    # 43. Premises; personal/cleaning items; vermi...
# 906012       # 25. Personal cleanliness and hair restraints
# 906013    # 33. Nonfood-contact surfaces clean and in go...
# Name: violation_description, Length: 906014, dtype: object

# %%
df2['violation_code'].value_counts()
# Out:
# violation_code
# F044    102012
# F033    100083
# F035     80020
# F040     50870
# F036     49744
#          ...
# MF42         1
# W045         1
# W022         1
# SS33         1
# CL21         1
# Name: count, Length: 116, dtype: int64

# %%
df1.describe()
# Out:
#        program_element_pe          score   service_code
# count       191371.000000  191371.000000  191371.000000
# mean          1629.888980      93.753306       7.078246
# std              9.391426       3.845518      48.932257
# min           1610.000000      54.000000       1.000000
# 25%           1631.000000      91.000000       1.000000
# 50%           1632.000000      94.000000       1.000000
# 75%           1635.000000      97.000000       1.000000
# max           1641.000000     100.000000     401.000000

# %%
df1.isnull().sum()
# program name has 402 null values
# Out:
# activity_date            0
# employee_id              0
# facility_address         0
# facility_city            0
# facility_id              0
# facility_name            0
# facility_state           0
# facility_zip             0
# grade                    0
# owner_id                 0
# owner_name               0
# pe_description           0
# program_element_pe       0
# program_name           402
# program_status           0
# record_id                0
# score                    0
# serial_number            0
# service_code             0
# service_description      0
# dtype: int64

# %%
df1['program_name']
# Out:
# 0          HOVIK'S FAMOUS MEAT & DELI
# 1                      SHAKEY'S PIZZA
# 2                      BAITH AL HALAL
# 3         FOOD 4 LESS DELI/BAKERY#306
# 4                   PHO LITTLE SAIGON
#                      ...
# 191366                      STARBUCKS
# 191367                    MOANA GRILL
# 191368                     QUEST CAFE
# 191369      PINA'S MEXICAN RESTAURANT
# 191370                RINCON HODURENO
# Name: program_name, Length: 191371, dtype: object

# %%
#let's see the 402 null values
df1[df1['program_name'].isna()]
# Out:
#        activity_date employee_id                     facility_address  \
# 75        2016-01-27   EE0000476                     757 S WORKMAN ST
# 841       2017-04-13   EE0000730                  20223 S AVALON BLVD
# 1418      2016-10-31   EE0000025             7201 1/2 LANKERSHIM BLVD
# 1419      2017-09-25   EE0000905  3650 W MARTIN LUTHER KING BLVD #140
# 2049      2016-02-01   EE0000997             3476 WHITTIER BLVD 101-2
# ...              ...         ...                                  ...
# 189677    2016-02-16   EE0000686                 3100 COUNTRY CLUB DR
# 190049    2016-08-04   EE0000905  3650 W MARTIN LUTHER KING BLVD #140
# 190206    2016-01-12   EE0000451                     10932 VANOWEN ST
# 190464    2015-10-02   EE0000893             210 W TEMPLE ST FL 5TH F
# 190960    2017-10-19   EE0000535                   14885 TELEGRAPH RD
#
#           facility_city facility_id             facility_name facility_state  \
# 75         SAN FERNANDO   FA0073233  VALLARTA SUPERMARKET #43             CA
# 841              CARSON   FA0137241              CARSON MOBIL             CA
# 1418    NORTH HOLLYWOOD   FA0010352             EL MICHOACANO             CA
# 1419        LOS ANGELES   FA0136799            YAKINIKU GRILL             CA
# 2049        LOS ANGELES   FA0136803          YOSHINOYA # 4124             CA
# ...                 ...         ...                       ...            ...
# 189677         GLENDALE   FA0002247      OAKMONT COUNTRY CLUB             CA
# 190049      LOS ANGELES   FA0136799            YAKINIKU GRILL             CA
# 190206  NORTH HOLLYWOOD   FA0032985    LAS CASITAS RESTAURANT             CA
# 190464      LOS ANGELES   FA0001579  CRIMINAL COURTS BUILDING             CA
# 190960        LA MIRADA   FA0136895          WALGREENS #13812             CA
#
#        facility_zip grade   owner_id                       owner_name  \
# 75            91340     A  OW0037169  VALLARTA FOOD ENTERPRISES, INC.
# 841           91746     A  OW0100065      PETROLEUM MANAGEMENT MARKET
# 1418     91605-3804     A  OW0100171                          DELTORO
# 1419     90008-1749     A  OW0099503            LOVE HOPE & FAITH LLC
# 2049          90023     A  OW0099510      S & S INVESTMENT GROUP INC.
# ...             ...   ...        ...                              ...
# 189677        91208     A  OW0026475         OAKMONT COUNTRY CLUB INC
# 190049   90008-1749     A  OW0099503            LOVE HOPE & FAITH LLC
# 190206        91605     B  OW0100160                   LOPEZ, RICHARD
# 190464        90012     A  OW0004223                  BEDIKIAM ZOHRAB
# 190960        90638     A  OW0038319                    WALGREENS CO.
#
#                                      pe_description  program_element_pe  \
# 75                RESTAURANT (0-30) SEATS HIGH RISK                1632
# 841            FOOD MKT RETAIL (2,000+ SF) LOW RISK                1613
# 1418              RESTAURANT (0-30) SEATS HIGH RISK                1632
# 1419              RESTAURANT (0-30) SEATS HIGH RISK                1632
# 2049         RESTAURANT (31-60) SEATS MODERATE RISK                1634
# ...                                             ...                 ...
# 189677          RESTAURANT (151 + ) SEATS HIGH RISK                1641
# 190049            RESTAURANT (0-30) SEATS HIGH RISK                1632
# 190206           RESTAURANT (31-60) SEATS HIGH RISK                1635
# 190464  FOOD MKT RETAIL (25-1,999 SF) MODERATE RISK                1611
# 190960         FOOD MKT RETAIL (2,000+ SF) LOW RISK                1613
#
#        program_name program_status  record_id  score serial_number  \
# 75              NaN         ACTIVE  PR0008831     91     DALU6RSNN
# 841             NaN         ACTIVE  PR0121221     91     DA7VBRCIY
# 1418            NaN         ACTIVE  PR0021927     95     DATQQIOAP
# 1419            NaN         ACTIVE  PR0120024     96     DAMS0EOBA
# 2049            NaN       INACTIVE  PR0120809     96     DAYIJ0QZ9
# ...             ...            ...        ...    ...           ...
# 189677          NaN         ACTIVE  PR0007165     91     DA9IMQY5L
# 190049          NaN         ACTIVE  PR0120024     90     DAX2YMOUH
# 190206          NaN       INACTIVE  PR0043835     87     DA0WFF2ES
# 190464          NaN         ACTIVE  PR0017495     97     DAY65WFDB
# 190960          NaN         ACTIVE  PR0120899     97     DAMJNPRDF
#
#         service_code service_description
# 75                 1  ROUTINE INSPECTION
# 841                1  ROUTINE INSPECTION
# 1418               1  ROUTINE INSPECTION
# 1419               1  ROUTINE INSPECTION
# 2049               1  ROUTINE INSPECTION
# ...              ...                 ...
# 189677             1  ROUTINE INSPECTION
# 190049             1  ROUTINE INSPECTION
# 190206             1  ROUTINE INSPECTION
# 190464             1  ROUTINE INSPECTION
# 190960             1  ROUTINE INSPECTION
#
# [402 rows x 20 columns]

# %%
#replace the null values with 'none'
df1.fillna('None',inplace=True)

# %%
df1.isnull().sum()
# Out:
# activity_date          0
# employee_id            0
# facility_address       0
# facility_city          0
# facility_id            0
# facility_name          0
# facility_state         0
# facility_zip           0
# grade                  0
# owner_id               0
# owner_name             0
# pe_description         0
# program_element_pe     0
# program_name           0
# program_status         0
# record_id              0
# score                  0
# serial_number          0
# service_code           0
# service_description    0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# points                   0
# serial_number            0
# violation_code           0
# violation_description    0
# violation_status         0
# dtype: int64

# %% [markdown]
# # Apply the inner join to both tables to analyze

# %%
df_inner=pd.merge(df1,df2,on='serial_number',how='inner')

# %%
df_inner
# Out:
#        activity_date employee_id        facility_address  facility_city  \
# 0         2017-05-09   EE0000593     17660 CHATSWORTH ST  GRANADA HILLS
# 1         2017-05-09   EE0000593     17660 CHATSWORTH ST  GRANADA HILLS
# 2         2017-04-10   EE0000126  3615 PACIFIC COAST HWY       TORRANCE
# 3         2017-04-10   EE0000126  3615 PACIFIC COAST HWY       TORRANCE
# 4         2017-04-10   EE0000126  3615 PACIFIC COAST HWY       TORRANCE
# ...              ...         ...                     ...            ...
# 897369    2017-03-20   EE0000800       1654 W ADAMS BLVD    LOS ANGELES
# 897370    2017-03-20   EE0000800       1654 W ADAMS BLVD    LOS ANGELES
# 897371    2017-03-20   EE0000800       1654 W ADAMS BLVD    LOS ANGELES
# 897372    2017-03-20   EE0000800       1654 W ADAMS BLVD    LOS ANGELES
# 897373    2017-03-20   EE0000800       1654 W ADAMS BLVD    LOS ANGELES
#
#        facility_id               facility_name facility_state facility_zip  \
# 0        FA0175397  HOVIK'S FAMOUS MEAT & DELI             CA        91344
# 1        FA0175397  HOVIK'S FAMOUS MEAT & DELI             CA        91344
# 2        FA0242138              SHAKEY'S PIZZA             CA        90505
# 3        FA0242138              SHAKEY'S PIZZA             CA        90505
# 4        FA0242138              SHAKEY'S PIZZA             CA        90505
# ...            ...                         ...            ...          ...
# 897369   FA0045805             RINCON HODURENO             CA        90007
# 897370   FA0045805             RINCON HODURENO             CA        90007
# 897371   FA0045805             RINCON HODURENO             CA        90007
# 897372   FA0045805             RINCON HODURENO             CA        90007
# 897373   FA0045805             RINCON HODURENO             CA        90007
#
#        grade   owner_id  ... program_status  record_id  score serial_number  \
# 0          A  OW0181955  ...         ACTIVE  PR0168541     98     DAHDRUQZO
# 1          A  OW0181955  ...         ACTIVE  PR0168541     98     DAHDRUQZO
# 2          A  OW0237843  ...         ACTIVE  PR0190290     94     DAL3SBUE0
# 3          A  OW0237843  ...         ACTIVE  PR0190290     94     DAL3SBUE0
# 4          A  OW0237843  ...         ACTIVE  PR0190290     94     DAL3SBUE0
# ...      ...        ...  ...            ...        ...    ...           ...
# 897369     A  OW0005012  ...         ACTIVE  PR0028225     95     DAOU061N2
# 897370     A  OW0005012  ...         ACTIVE  PR0028225     95     DAOU061N2
# 897371     A  OW0005012  ...         ACTIVE  PR0028225     95     DAOU061N2
# 897372     A  OW0005012  ...         ACTIVE  PR0028225     95     DAOU061N2
# 897373     A  OW0005012  ...         ACTIVE  PR0028225     95     DAOU061N2
#
#        service_code service_description  points violation_code  \
# 0                 1  ROUTINE INSPECTION       1           F029
# 1                 1  ROUTINE INSPECTION       1           F033
# 2                 1  ROUTINE INSPECTION       1           F035
# 3                 1  ROUTINE INSPECTION       1           F044
# 4                 1  ROUTINE INSPECTION       1           F033
# ...             ...                 ...     ...            ...
# 897369            1  ROUTINE INSPECTION       1           F036
# 897370            1  ROUTINE INSPECTION       1           F027
# 897371            1  ROUTINE INSPECTION       1           F030
# 897372            1  ROUTINE INSPECTION       1           F037
# 897373            1  ROUTINE INSPECTION       1           F035
#
#                                     violation_description   violation_status
# 0       # 29. Toxic substances properly identified, st...  OUT OF COMPLIANCE
# 1       # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
# 2       # 35. Equipment/Utensils - approved; installed...  OUT OF COMPLIANCE
# 3       # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 4       # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
# ...                                                   ...                ...
# 897369  # 36. Equipment, utensils and linens: storage ...  OUT OF COMPLIANCE
# 897370                 # 27. Food separated and protected  OUT OF COMPLIANCE
# 897371  # 30. Food properly stored; food storage conta...  OUT OF COMPLIANCE
# 897372  # 37. Adequate ventilation and lighting; desig...  OUT OF COMPLIANCE
# 897373  # 35. Equipment/Utensils - approved; installed...  OUT OF COMPLIANCE
#
# [897374 rows x 24 columns]

# %% [markdown]
# # Which facility address has the violation code F044

# %%
common_violation_code=df_inner.loc[df_inner['violation_code']=='F044']
common_violation_code
# Out:
#        activity_date employee_id           facility_address   facility_city  \
# 3         2017-04-10   EE0000126     3615 PACIFIC COAST HWY        TORRANCE
# 8         2017-04-04   EE0000593        17515 CHATSWORTH ST   GRANADA HILLS
# 17        2016-09-26   EE0000145             11700 SOUTH ST         ARTESIA
# 23        2017-02-28   EE0000741             4959 PATATA ST          CUDAHY
# 32        2016-11-03   EE0000721              524 S MAIN ST     LOS ANGELES
# ...              ...         ...                        ...             ...
# 897329    2017-07-24   EE0000726     7871 SANTA MONICA BLVD  WEST HOLLYWOOD
# 897333    2016-05-24   EE0000839          8409 S 8TH AVE #A       INGLEWOOD
# 897345    2017-04-05   EE0000503      11750 E WHITTIER BLVD        WHITTIER
# 897350    2016-08-17   EE0000018  15420 S WESTERN AVE STE A         GARDENA
# 897359    2016-06-30   EE0000029         11976 ARTESIA BLVD         ARTESIA
#
#        facility_id                 facility_name facility_state facility_zip  \
# 3        FA0242138                SHAKEY'S PIZZA             CA        90505
# 8        FA0007801                BAITH AL HALAL             CA        91344
# 17       FA0179671             PHO LITTLE SAIGON             CA        90701
# 23       FA0012590               EL POTRERO CLUB             CA        90201
# 32       FA0051633              THE NICKEL DINER             CA        90013
# ...            ...                           ...            ...          ...
# 897329   FA0040885        WHOLE FOODS MARKET #20             CA        90069
# 897333   FA0036085  LOUISIANA FRIED CHICKEN #380             CA        90305
# 897345   FA0034394              STATER BROS #137             CA        90602
# 897350   FA0174778                   MOANA GRILL             CA        90249
# 897359   FA0029343                    QUEST CAFE             CA        90701
#
#        grade   owner_id  ... program_status  record_id  score serial_number  \
# 3          A  OW0237843  ...         ACTIVE  PR0190290     94     DAL3SBUE0
# 8          A  OW0031150  ...       INACTIVE  PR0036723     95     DAL2PIKJU
# 17         A  OW0185167  ...         ACTIVE  PR0173311     96     DA41DBXA2
# 23         B  OW0036634  ...         ACTIVE  PR0041708     87     DAUNXDSVP
# 32         A  OW0004308  ...         ACTIVE  PR0000202     96     DAFLSXKZ2
# ...      ...        ...  ...            ...        ...    ...           ...
# 897329     A  OW0038850  ...         ACTIVE  PR0007800     98     DA2JHH6YR
# 897333     A  OW0101143  ...       INACTIVE  PR0038901     97     DAEMF9KLM
# 897345     A  OW0033964  ...         ACTIVE  PR0014518     97     DA0LTBR5H
# 897350     A  OW0181412  ...         ACTIVE  PR0167828     92     DAV0HVX0C
# 897359     A  OW0018341  ...       INACTIVE  PR0042814     90     DATL8XDYB
#
#        service_code service_description  points violation_code  \
# 3                 1  ROUTINE INSPECTION       1           F044
# 8                 1  ROUTINE INSPECTION       1           F044
# 17                1  ROUTINE INSPECTION       1           F044
# 23                1  ROUTINE INSPECTION       1           F044
# 32                1  ROUTINE INSPECTION       1           F044
# ...             ...                 ...     ...            ...
# 897329            1  ROUTINE INSPECTION       1           F044
# 897333            1  ROUTINE INSPECTION       1           F044
# 897345            1  ROUTINE INSPECTION       1           F044
# 897350            1  ROUTINE INSPECTION       1           F044
# 897359            1  ROUTINE INSPECTION       1           F044
#
#                                     violation_description   violation_status
# 3       # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 8       # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 17      # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 23      # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 32      # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# ...                                                   ...                ...
# 897329  # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 897333  # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 897345  # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 897350  # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 897359  # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
#
# [101243 rows x 24 columns]

# %%
df_inner.isnull().sum()
# Out:
# activity_date            0
# employee_id              0
# facility_address         0
# facility_city            0
# facility_id              0
# facility_name            0
# facility_state           0
# facility_zip             0
# grade                    0
# owner_id                 0
# owner_name               0
# pe_description           0
# program_element_pe       0
# program_name             0
# program_status           0
# record_id                0
# score                    0
# serial_number            0
# service_code             0
# service_description      0
# points                   0
# violation_code           0
# violation_description    0
# violation_status         0
# dtype: int64

# %%
df_inner['violation_description'].value_counts()
# Out:
# violation_description
# # 44. Floors, walls and ceilings: properly built, maintained in good repair and clean    101243
# # 33. Nonfood-contact surfaces clean and in good repair                                   99451
# # 35. Equipment/Utensils - approved; installed; clean; good repair, capacity              79043
# # 40. Plumbing: Plumbing in good repair, proper backflow devices                          50491
# # 36. Equipment, utensils and linens: storage and use                                     49464
#                                                                                           ...
# Food packaging protected                                                                      1
# Permit Suspension                                                                             1
# Ceiling constructed of smooth, durable, and non-absorbent material                            1
# Building rodent proof                                                                         1
# Proper storage or use of hazardous materials                                                  1
# Name: count, Length: 87, dtype: int64

# %%
df_inner.to_csv('inner_join.csv')
